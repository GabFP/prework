# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
choices = ('stone', 'paper', 'scissors')
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
limitGames = 3
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
gamesToWin = limitGames-int(limitGames/2)
# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def computerchoice(choices):
    return random.choice(choices)
# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def playerchoice(choices):
    hasntchosen = True
    while hasntchosen:
        print("chose between:", choices)
        choice = input()
        if(choice in choices):
            hasntchosen = False
        else:
            print("chose again:")
    return choice
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def jokempo(human,ai, choices):
    humanindex = choices.index(human)
    aiindex = choices.index(ai)
    if(humanindex==aiindex):
        return 0
    elif(humanindex==aiindex+1 or humanindex+1==aiindex-1):
        return 2
    elif(aiindex==humanindex+1 or aiindex+1==humanindex-1):
        return 1
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def combat(human, ai, choices):
    print("you chose:", human)
    print("the computer chose:", ai)
    if(jokempo(human,ai,choices)==0):
        print("this round was a tie")
        return 0
    elif(jokempo(human,ai,choices)==1):
        print("the computer won this round")
        return 1
    else:
        print("you won this round")
        return 2
# Create two variables that accumulate the wins of each participant
humanwins = 0
aiwins = 0
ties = 0
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while(humanwins != gamesToWin or aiwins != gamesToWin):
    result = combat(playerchoice(choices), computerchoice(choices), choices)
    if(result==1):
        aiwins+=1
    elif(result==2):
        humanwins+=1
    elif(result==0):
        ties+=1
    if(aiwins>=gamesToWin):
        print("the computer won the game")
        print("score:")
        print("player:", humanwins)
        print("computer:", aiwins)
        print("ties:", ties)
        break
    elif(humanwins>=gamesToWin):
        print("you won the game")
        print("score:")
        print("player:", humanwins)
        print("computer:", aiwins)
        print("ties:", ties)
        break
    print("score:")
    print("player:", humanwins)
    print("computer:", aiwins)
    print("ties:", ties)

    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# chose between: ('stone', 'paper', 'scissors')
# stone
# you chose: stone
# the computer chose: stone
# this round was a tie
# score:
# player: 0
# computer: 0
# ties: 1
# chose between: ('stone', 'paper', 'scissors')
# paper
# you chose: paper
# the computer chose: paper
# this round was a tie
# score:
# player: 0
# computer: 0
# ties: 2
# chose between: ('stone', 'paper', 'scissors')
# stone
# you chose: stone
# the computer chose: scissors
# you won this round
# score:
# player: 1
# computer: 0
# ties: 2
# chose between: ('stone', 'paper', 'scissors')
# scissors
# you chose: scissors
# the computer chose: stone
# the computer won this round
# score:
# player: 1
# computer: 1
# ties: 2
# chose between: ('stone', 'paper', 'scissors')
# paper
# you chose: paper
# the computer chose: stone
# you won this round
# you won the game
# score:
# player: 2
# computer: 1
# ties: 2

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def askmaxgames():
    choiceisdone = False
    while(choiceisdone==False):
        print("chose the number of rounds:")
        maxgames = int(input())
        if(maxgames%2==1):
            return maxgames
# Assign a list of 5 possible options.
choices = ('stone', 'paper', 'scissors', 'spock', 'lizard')
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
maxgames = askmaxgames()
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
gamesToWin = maxgames - int(maxgames/2)
# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def computerchoice(choices):
    return random.choice(choices)
# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def playerchoice(choices):
    hasntchosen = True
    while hasntchosen:
        print("chose between:", choices)
        choice = input()
        if(choice in choices):
            hasntchosen = False
        else:
            print("chose again:")
    return choice
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def jokempo(human,ai, choices):
    humanindex = choices.index(human)
    aiindex = choices.index(ai)
    if(humanindex==aiindex):
        return 0
    elif(humanindex==aiindex+1 or humanindex+1==aiindex-1 or humanindex==0 and aiindex==len(choices)-1):
        return 2
    elif(aiindex==humanindex+1 or aiindex+1==humanindex-1 or aiindex==0 and humanindex==len(choices)-1):
        return 1
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def combat(human, ai, choices):
    print("you chose:", human)
    print("the computer chose:", ai)
    if(jokempo(human,ai,choices)==0):
        print("this round was a tie")
        return 0
    elif(jokempo(human,ai,choices)==1):
        print("the computer won this round")
        return 1
    else:
        print("you won this round")
        return 2
# Create two variables that accumulate the wins of each participant
humanwins = 0
aiwins = 0
ties = 0
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while(humanwins != gamesToWin or aiwins != gamesToWin):
    result = combat(playerchoice(choices), computerchoice(choices), choices)
    if(result==1):
        aiwins+=1
    elif(result==2):
        humanwins+=1
    elif(result==0):
        ties+=1
    if(aiwins>=gamesToWin):
        print("the computer won the game")
        print("score:")
        print("player:", humanwins)
        print("computer:", aiwins)
        print("ties:", ties)
        break
    elif(humanwins>=gamesToWin):
        print("you won the game")
        print("score:")
        print("player:", humanwins)
        print("computer:", aiwins)
        print("ties:", ties)
        break
    print("score:")
    print("player:", humanwins)
    print("computer:", aiwins)
    print("ties:", ties)
    
    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# chose the number of rounds:
# 5
# chose between: ('stone', 'paper', 'scissors', 'spock', 'lizard')
# stone
# you chose: stone
# the computer chose: scissors
# you won this round
# score:
# player: 1
# computer: 0
# ties: 0
# chose between: ('stone', 'paper', 'scissors', 'spock', 'lizard')
# spock
# you chose: spock
# the computer chose: lizard
# the computer won this round
# score:
# player: 1
# computer: 1
# ties: 0
# chose between: ('stone', 'paper', 'scissors', 'spock', 'lizard')
# lizard
# you chose: lizard
# the computer chose: paper
# you won this round
# score:
# player: 2
# computer: 1
# ties: 0
# chose between: ('stone', 'paper', 'scissors', 'spock', 'lizard')
# paper
# you chose: paper
# the computer chose: scissors
# the computer won this round
# score:
# player: 2
# computer: 2
# ties: 0
# chose between: ('stone', 'paper', 'scissors', 'spock', 'lizard')
# stone
# you chose: stone
# the computer chose: paper
# the computer won this round
# the computer won the game
# score:
# player: 2
# computer: 3
# ties: 0
